# %%
import pandas as pd
import os 
import shutil

# %%
FILE_PATH = "PC/PADCHEST_chest_x_ray_images_labels_160K_01.02.19.csv"

# %%
df = pd.read_csv(FILE_PATH)
# Out:
# C:\Users\rizvee\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.shape
# Out:
# (160861, 36)

# %%
df.head()
# Out:
#    Unnamed: 0                                            ImageID  ImageDir  \
# 0           0  20536686640136348236148679891455886468_k6ga29.png         0
# 1           1  135803415504923515076821959678074435083_fzis7d...         0
# 2           2  135803415504923515076821959678074435083_fzis7b...         0
# 3           3  113855343774216031107737439268243531979_3k951l...         0
# 4           4  113855343774216031107737439268243531979_3k951n...         0
#
#    StudyDate_DICOM                                  StudyID  \
# 0         20140915   20536686640136348236148679891455886468
# 1         20150914  135803415504923515076821959678074435083
# 2         20150914  135803415504923515076821959678074435083
# 3         20150717  113855343774216031107737439268243531979
# 4         20150717  113855343774216031107737439268243531979
#
#                                  PatientID  PatientBirth PatientSex_DICOM  \
# 0     839860488694292331637988235681460987        1930.0                F
# ...

# %%
TARGET_DIR = "D:/thesis/dataset/Normal"
IMAGES_PATH = "D:/thesis/PC/images-224"
if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("Normal Folder Created")

# %%
cnt = 0

for(i,row) in df.iterrows():
    if row["Labels"]==target and row["Projection"]=="PA":
        filename=row["ImageID"]
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image", cnt)
        cnt+=1
# Out:
# moving image 0
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# moving image 12
# moving image 13
# moving image 14
# moving image 15
# moving image 16
# moving image 17
# moving image 18
# moving image 19
# moving image 20
# moving image 21
# moving image 22
# moving image 23
# moving image 24
# moving image 25
# moving image 26
# moving image 27
# moving image 28
# moving image 29
# moving image 30
# moving image 31
# moving image 32
# moving image 33
# moving image 34
# moving image 35
# moving image 36
# moving image 37
# moving image 38
# moving image 39
# moving image 40
# moving image 41
# moving image 42
# moving image 43
# moving image 44
# moving image 45
# moving image 46
# moving image 47
# moving image 48
# moving image 49
# moving image 50
# moving image 51
# moving image 52
# moving image 53
# moving image 54
# moving image 55
# ...

# %%
TARGET_DIR = "D:/thesis/dataset/COPD_Signs"

if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("COPD_Signs Folder Created")

# %%
cnt = 0
target = "[\'COPD signs\']"
for(i,row) in df.iterrows():
    if row["Labels"]==target and row["Projection"]=="PA":
        filename=row["ImageID"]
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image", cnt)
        cnt+=1
# Out:
# moving image 0
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# moving image 12
# moving image 13
# moving image 14
# moving image 15
# moving image 16
# moving image 17
# moving image 18
# moving image 19
# moving image 20
# moving image 21
# moving image 22
# moving image 23
# moving image 24
# moving image 25
# moving image 26
# moving image 27
# moving image 28
# moving image 29
# moving image 30
# moving image 31
# moving image 32
# moving image 33
# moving image 34
# moving image 35
# moving image 36
# moving image 37
# moving image 38
# moving image 39
# moving image 40
# moving image 41
# moving image 42
# moving image 43
# moving image 44
# moving image 45
# moving image 46
# moving image 47
# moving image 48
# moving image 49
# moving image 50
# moving image 51
# moving image 52
# moving image 53
# moving image 54
# moving image 55
# ...

# %%
TARGET_DIR = "D:/thesis/dataset/Scoliosis"

if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("Scoliosis Folder Created")
# Out:
# Scoliosis Folder Created

# %%
cnt = 0
target = "[\'scoliosis\']"
for(i,row) in df.iterrows():
    if row["Labels"]==target and row["Projection"]=="PA":
        filename=row["ImageID"]
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image", cnt)
        cnt+=1
# Out:
# moving image 0
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# moving image 12
# moving image 13
# moving image 14
# moving image 15
# moving image 16
# moving image 17
# moving image 18
# moving image 19
# moving image 20
# moving image 21
# moving image 22
# moving image 23
# moving image 24
# moving image 25
# moving image 26
# moving image 27
# moving image 28
# moving image 29
# moving image 30
# moving image 31
# moving image 32
# moving image 33
# moving image 34
# moving image 35
# moving image 36
# moving image 37
# moving image 38
# moving image 39
# moving image 40
# moving image 41
# moving image 42
# moving image 43
# moving image 44
# moving image 45
# moving image 46
# moving image 47
# moving image 48
# moving image 49
# moving image 50
# moving image 51
# moving image 52
# moving image 53
# moving image 54
# moving image 55
# ...

# %%
TARGET_DIR = "D:/thesis/dataset/Air_trapping"

if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("Air_trapping Folder Created")
# Out:
# Air_trapping Folder Created

# %%
cnt = 0
target = "[\'air trapping\']"
for(i,row) in df.iterrows():
    if row["Labels"]==target and row["Projection"]=="PA":
        filename=row["ImageID"]
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image", cnt)
        cnt+=1
print(cnt)
# Out:
# moving image 0
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# moving image 12
# moving image 13
# moving image 14
# moving image 15
# moving image 16
# moving image 17
# moving image 18
# moving image 19
# moving image 20
# moving image 21
# moving image 22
# moving image 23
# moving image 24
# moving image 25
# moving image 26
# moving image 27
# moving image 28
# moving image 29
# moving image 30
# moving image 31
# moving image 32
# moving image 33
# moving image 34
# moving image 35
# moving image 36
# moving image 37
# moving image 38
# moving image 39
# moving image 40
# moving image 41
# moving image 42
# moving image 43
# moving image 44
# moving image 45
# moving image 46
# moving image 47
# moving image 48
# moving image 49
# moving image 50
# moving image 51
# moving image 52
# moving image 53
# moving image 54
# moving image 55
# ...

# %%
TARGET_DIR = "D:/thesis/dataset/Aortic_elongation"

if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("Aortic_elongation Folder Created")
# Out:
# Aortic_elongation Folder Created

# %%
cnt = 0
target = "[\'aortic elongation\']"
for(i,row) in df.iterrows():
    if row["Labels"]==target and row["Projection"]=="PA":
        filename=row["ImageID"]
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image", cnt)
        cnt+=1
print(cnt)
# Out:
# moving image 0
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# moving image 12
# moving image 13
# moving image 14
# moving image 15
# moving image 16
# moving image 17
# moving image 18
# moving image 19
# moving image 20
# moving image 21
# moving image 22
# moving image 23
# moving image 24
# moving image 25
# moving image 26
# moving image 27
# moving image 28
# moving image 29
# moving image 30
# moving image 31
# moving image 32
# moving image 33
# moving image 34
# moving image 35
# moving image 36
# moving image 37
# moving image 38
# moving image 39
# moving image 40
# moving image 41
# moving image 42
# moving image 43
# moving image 44
# moving image 45
# moving image 46
# moving image 47
# moving image 48
# moving image 49
# moving image 50
# moving image 51
# moving image 52
# moving image 53
# moving image 54
# moving image 55
# ...

# %%
TARGET_DIR = "D:/thesis/dataset/Pleural_effusion"

if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("Pleural_effusion Folder Created")
# Out:
# Pleural_effusion Folder Created

# %%
cnt = 0
target = "[\'pleural effusion\']"
for(i,row) in df.iterrows():
    if row["Labels"]==target and row["Projection"]=="PA":
        filename=row["ImageID"]
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image", cnt)
        cnt+=1
print(cnt)
# Out:
# moving image 0
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# moving image 12
# moving image 13
# moving image 14
# moving image 15
# moving image 16
# moving image 17
# moving image 18
# moving image 19
# moving image 20
# moving image 21
# moving image 22
# moving image 23
# moving image 24
# moving image 25
# moving image 26
# moving image 27
# moving image 28
# moving image 29
# moving image 30
# moving image 31
# moving image 32
# moving image 33
# moving image 34
# moving image 35
# moving image 36
# moving image 37
# moving image 38
# moving image 39
# moving image 40
# moving image 41
# moving image 42
# moving image 43
# moving image 44
# moving image 45
# moving image 46
# moving image 47
# moving image 48
# moving image 49
# moving image 50
# moving image 51
# moving image 52
# moving image 53
# moving image 54
# moving image 55
# ...

# %%
TARGET_DIR = "D:/thesis/dataset/Laminar_atelectasis"

if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("Laminar_atelectasis Folder Created")
# Out:
# Laminar_atelectasis Folder Created

# %%
cnt = 0
target = "[\'laminar atelectasis\']"
for(i,row) in df.iterrows():
    if row["Labels"]==target and row["Projection"]=="PA":
        filename=row["ImageID"]
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image", cnt)
        cnt+=1
print(cnt)
# Out:
# moving image 0
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# moving image 12
# moving image 13
# moving image 14
# moving image 15
# moving image 16
# moving image 17
# moving image 18
# moving image 19
# moving image 20
# moving image 21
# moving image 22
# moving image 23
# moving image 24
# moving image 25
# moving image 26
# moving image 27
# moving image 28
# moving image 29
# moving image 30
# moving image 31
# moving image 32
# moving image 33
# moving image 34
# moving image 35
# moving image 36
# moving image 37
# moving image 38
# moving image 39
# moving image 40
# moving image 41
# moving image 42
# moving image 43
# moving image 44
# moving image 45
# moving image 46
# moving image 47
# moving image 48
# moving image 49
# moving image 50
# moving image 51
# moving image 52
# moving image 53
# moving image 54
# moving image 55
# ...

# %%
TARGET_DIR = "D:/thesis/dataset/Callus_rib_fracture"

if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("Callus_rib_fracture Folder Created")
# Out:
# Callus_rib_fracture Folder Created

# %%
cnt = 0
target = "[\'callus rib fracture\']"
for(i,row) in df.iterrows():
    if row["Labels"]==target and row["Projection"]=="PA":
        filename=row["ImageID"]
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image", cnt)
        cnt+=1
print(cnt)
# Out:
# moving image 0
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# moving image 12
# moving image 13
# moving image 14
# moving image 15
# moving image 16
# moving image 17
# moving image 18
# moving image 19
# moving image 20
# moving image 21
# moving image 22
# moving image 23
# moving image 24
# moving image 25
# moving image 26
# moving image 27
# moving image 28
# moving image 29
# moving image 30
# moving image 31
# moving image 32
# moving image 33
# moving image 34
# moving image 35
# moving image 36
# moving image 37
# moving image 38
# moving image 39
# moving image 40
# moving image 41
# moving image 42
# moving image 43
# moving image 44
# moving image 45
# moving image 46
# moving image 47
# moving image 48
# moving image 49
# moving image 50
# moving image 51
# moving image 52
# moving image 53
# moving image 54
# moving image 55
# ...

# %%
TARGET_DIR = "D:/thesis/dataset/Kyphosis"

if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("Kyphosis Folder Created")
# Out:
# Kyphosis Folder Created

# %%
cnt = 0
target = "[\'kyphosis\']"
for(i,row) in df.iterrows():
    if row["Labels"]==target and row["Projection"]=="PA":
        filename=row["ImageID"]
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image", cnt)
        cnt+=1
print(cnt)
# Out:
# moving image 0
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# moving image 12
# moving image 13
# moving image 14
# moving image 15
# moving image 16
# moving image 17
# moving image 18
# moving image 19
# moving image 20
# moving image 21
# moving image 22
# moving image 23
# moving image 24
# moving image 25
# moving image 26
# moving image 27
# moving image 28
# moving image 29
# moving image 30
# moving image 31
# moving image 32
# moving image 33
# moving image 34
# moving image 35
# moving image 36
# moving image 37
# moving image 38
# moving image 39
# moving image 40
# moving image 41
# moving image 42
# moving image 43
# moving image 44
# moving image 45
# moving image 46
# moving image 47
# moving image 48
# moving image 49
# moving image 50
# moving image 51
# moving image 52
# moving image 53
# moving image 54
# moving image 55
# ...

# %%
TARGET_DIR = "D:/thesis/dataset/Hiatal_hernia"

if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("Hiatal_hernia Folder Created")
# Out:
# Hiatal_hernia Folder Created

# %%
cnt = 0
target = "[\'hiatal hernia\']"
for(i,row) in df.iterrows():
    if row["Labels"]==target and row["Projection"]=="PA":
        filename=row["ImageID"]
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image", cnt)
        cnt+=1
print(cnt)
# Out:
# moving image 0
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# moving image 12
# moving image 13
# moving image 14
# moving image 15
# moving image 16
# moving image 17
# moving image 18
# moving image 19
# moving image 20
# moving image 21
# moving image 22
# moving image 23
# moving image 24
# moving image 25
# moving image 26
# moving image 27
# moving image 28
# moving image 29
# moving image 30
# moving image 31
# moving image 32
# moving image 33
# moving image 34
# moving image 35
# moving image 36
# moving image 37
# moving image 38
# moving image 39
# moving image 40
# moving image 41
# moving image 42
# moving image 43
# moving image 44
# moving image 45
# moving image 46
# moving image 47
# moving image 48
# moving image 49
# moving image 50
# moving image 51
# moving image 52
# moving image 53
# moving image 54
# moving image 55
# ...

# %%
TARGET_DIR = "D:/thesis/dataset/Vascular_hilar_enlargement"

if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("Vascular_hilar_enlargement Folder Created")
# Out:
# Vascular_hilar_enlargement Folder Created

# %%
cnt = 0
target = "[\'vascular hilar enlargement\']"
for(i,row) in df.iterrows():
    if row["Labels"]==target and row["Projection"]=="PA":
        filename=row["ImageID"]
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image", cnt)
        cnt+=1
print(cnt)
# Out:
# moving image 0
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# moving image 12
# moving image 13
# moving image 14
# moving image 15
# moving image 16
# moving image 17
# moving image 18
# moving image 19
# moving image 20
# moving image 21
# moving image 22
# moving image 23
# moving image 24
# moving image 25
# moving image 26
# moving image 27
# moving image 28
# moving image 29
# moving image 30
# moving image 31
# moving image 32
# moving image 33
# moving image 34
# moving image 35
# moving image 36
# moving image 37
# moving image 38
# moving image 39
# moving image 40
# moving image 41
# moving image 42
# moving image 43
# moving image 44
# moving image 45
# moving image 46
# moving image 47
# moving image 48
# moving image 49
# moving image 50
# moving image 51
# moving image 52
# moving image 53
# moving image 54
# moving image 55
# ...

# %%
TARGET_DIR = "D:/thesis/dataset/Calcified_granuloma"

if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("Calcified_granuloma Folder Created")
# Out:
# Calcified_granuloma Folder Created

# %%
cnt = 0
target = "[\'calcified granuloma\']"
for(i,row) in df.iterrows():
    if row["Labels"]==target and row["Projection"]=="PA":
        filename=row["ImageID"]
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image", cnt)
        cnt+=1
print(cnt)
# Out:
# moving image 0
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# moving image 12
# moving image 13
# moving image 14
# moving image 15
# moving image 16
# moving image 17
# moving image 18
# moving image 19
# moving image 20
# moving image 21
# moving image 22
# moving image 23
# moving image 24
# moving image 25
# moving image 26
# moving image 27
# moving image 28
# moving image 29
# moving image 30
# moving image 31
# moving image 32
# moving image 33
# moving image 34
# moving image 35
# moving image 36
# moving image 37
# moving image 38
# moving image 39
# moving image 40
# moving image 41
# moving image 42
# moving image 43
# moving image 44
# moving image 45
# moving image 46
# moving image 47
# moving image 48
# moving image 49
# moving image 50
# moving image 51
# moving image 52
# moving image 53
# moving image 54
# moving image 55
# ...
